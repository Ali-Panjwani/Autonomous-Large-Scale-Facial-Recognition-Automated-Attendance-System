# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read an excel file
#df = pd.read_excel('/FAST School of Computing Spring 2023- V3.xlsx')

# Show the first 5 rows of the data
#print(df.head())

# Load the workbook into a pandas ExcelFile object
xl = pd.ExcelFile('/FAST School of Computing Spring 2023- V3.xlsx')

# Load each sheet into a pandas DataFrame
sheet1 = xl.parse(xl.sheet_names[0])
sheet2 = xl.parse(xl.sheet_names[1])
sheet3 = xl.parse(xl.sheet_names[2])
sheet4 = xl.parse(xl.sheet_names[3])

# Print the first 5 rows of each sheet
print("First 5 rows of sheet 1:\n", sheet1.head())
print("First 5 rows of sheet 2:\n", sheet2.head())
print("First 5 rows of sheet 3:\n", sheet3.head())
print("First 5 rows of sheet 4:\n", sheet4.head())
# Out:
# First 5 rows of sheet 1:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11  \
# 0         NaN        NaN        NaN         NaN          NaN         NaN
# 1         NaN        NaN        NaN         NaN          NaN         NaN
# 2         NaN        NaN        NaN         NaN          NaN         NaN
# 3         NaN        NaN        NaN         NaN          NaN         NaN
# 4         NaN        NaN        NaN         NaN          NaN         NaN
#
# ...

# %%
xl = pd.ExcelFile('/FAST School of Computing Spring 2023- V3.xlsx')
# Get a list of all the sheet names in the workbook
sheet_names = xl.sheet_names

# Define the name of the sheet to search for
sheet_name = 'MONDAY'

# Check if the sheet name exists in the list of sheet names
if sheet_name in sheet_names:
    # Load the specified sheet into a pandas DataFrame
    df = xl.parse(sheet_name)
    
    #print(df.head())
    print(df)
else:
    print(f'Sheet "{sheet_name}" not found in workbook.')
# Out:
#             MONDAY                           Unnamed: 1  \
# 0            Slots                                    1
# 1      Venues/time                              08-8:55
# 2       CLASSROOMS                                  NaN
# 3        E1 CS(60)                                  NaN
# 4       E2 CS (60)                AI BCS-6E\nDr. Waheed
# 5       E3 CS (60)                                  NaN
# 6       E4 CS (60)               SE BCS-6B\nDr. Muazzam
# 7       E5 CS (60)        AI BCS-6A\nDr. Fahad Sherwani
# 8       E6 CS (60)                                  NaN
# 9      R11 CS (50)         CN BCS-6C\nDr. Farrukh Salim
# 10     R12 CS (70)                     CN BCS-6D\nYusra
# 11    R109 CS (50)                      RS BSE-6A\nZain
# 12     A-1 EE (72)                    AI BCS-6F\nSaeeda
# 13     A-2 EE (72)                    CPS BSE-2A\nAtifa
# 14     A-3 EE (72)                   DLD BCS-2F\nKashan
# 15     A-4 EE (72)                  COAL BCY-4A\nAashir
# ...
